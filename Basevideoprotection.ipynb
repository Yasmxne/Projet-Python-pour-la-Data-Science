# %% [markdown]
# ## Accès à la base de données des équipements de vidéoprotection depuis une API et importation du DataFrame
#
# A partir du site internet [data.gouv](https://www.data.gouv.fr/fr/datasets/emplacements-dimplantation-de-cameras-de-videoprotection-bo-ville-de-paris-du-01-02-2019/), nous mettons en place une API pour récuperer les données (en version beta lors de l'écriture du présent).
# Nous récupérons l'ID du jeu de données (ici : 0f195145-1f5a-4762-9edc-40031ba4402f).

# %%
# !pip install py7zr geopandas openpyxl tqdm s3fs
# !pip install PyYAML xlrd
# !pip install git+https://github.com/inseefrlab/cartiflette
import pandas as pd
import geopandas as gpd
import requests
import matplotlib.pyplot as plt
from cartiflette import carti_download
import folium
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: py7zr in /home/yasmine/.local/lib/python3.10/site-packages (0.20.8)
# Requirement already satisfied: geopandas in /home/yasmine/.local/lib/python3.10/site-packages (1.0.1)
# Requirement already satisfied: openpyxl in /home/yasmine/.local/lib/python3.10/site-packages (3.1.5)
# Requirement already satisfied: tqdm in /home/yasmine/.local/lib/python3.10/site-packages (4.66.1)
# Requirement already satisfied: s3fs in /home/yasmine/.local/lib/python3.10/site-packages (2023.12.2)
# Requirement already satisfied: pyppmd<1.2.0,>=1.1.0 in /home/yasmine/.local/lib/python3.10/site-packages (from py7zr) (1.1.1)
# Requirement already satisfied: texttable in /home/yasmine/.local/lib/python3.10/site-packages (from py7zr) (1.7.0)
# Requirement already satisfied: pycryptodomex>=3.16.0 in /home/yasmine/.local/lib/python3.10/site-packages (from py7zr) (3.21.0)
# Requirement already satisfied: pybcj<1.1.0,>=1.0.0 in /home/yasmine/.local/lib/python3.10/site-packages (from py7zr) (1.0.3)
# Requirement already satisfied: multivolumefile>=0.2.3 in /home/yasmine/.local/lib/python3.10/site-packages (from py7zr) (0.2.3)
# Requirement already satisfied: inflate64<1.1.0,>=1.0.0 in /home/yasmine/.local/lib/python3.10/site-packages (from py7zr) (1.0.1)
# Requirement already satisfied: pyzstd>=0.15.9 in /home/yasmine/.local/lib/python3.10/site-packages (from py7zr) (0.16.2)
# Requirement already satisfied: psutil in /home/yasmine/.local/lib/python3.10/site-packages (from py7zr) (5.9.5)
# Requirement already satisfied: brotli>=1.1.0 in /home/yasmine/.local/lib/python3.10/site-packages (from py7zr) (1.1.0)
# Requirement already satisfied: numpy>=1.22 in /home/yasmine/.local/lib/python3.10/site-packages (from geopandas) (1.26.2)
# Requirement already satisfied: pyogrio>=0.7.2 in /home/yasmine/.local/lib/python3.10/site-packages (from geopandas) (0.9.0)
# Requirement already satisfied: pyproj>=3.3.0 in /home/yasmine/.local/lib/python3.10/site-packages (from geopandas) (3.6.1)
# Requirement already satisfied: pandas>=1.4.0 in /home/yasmine/.local/lib/python3.10/site-packages (from geopandas) (2.2.2)
# Requirement already satisfied: shapely>=2.0.0 in /home/yasmine/.local/lib/python3.10/site-packages (from geopandas) (2.0.5)
# Requirement already satisfied: packaging in /home/yasmine/.local/lib/python3.10/site-packages (from geopandas) (23.2)
# Requirement already satisfied: et-xmlfile in /usr/lib/python3/dist-packages (from openpyxl) (1.0.1)
# Requirement already satisfied: aiobotocore<3.0.0,>=2.5.4 in /home/yasmine/.local/lib/python3.10/site-packages (from s3fs) (2.16.1)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /home/yasmine/.local/lib/python3.10/site-packages (from s3fs) (3.11.11)
# Requirement already satisfied: fsspec==2023.12.2 in /home/yasmine/.local/lib/python3.10/site-packages (from s3fs) (2023.12.2)
# Requirement already satisfied: botocore<1.35.89,>=1.35.74 in /home/yasmine/.local/lib/python3.10/site-packages (from aiobotocore<3.0.0,>=2.5.4->s3fs) (1.35.88)
# Requirement already satisfied: wrapt<2.0.0,>=1.10.10 in /home/yasmine/.local/lib/python3.10/site-packages (from aiobotocore<3.0.0,>=2.5.4->s3fs) (1.14.1)
# Requirement already satisfied: aioitertools<1.0.0,>=0.5.1 in /home/yasmine/.local/lib/python3.10/site-packages (from aiobotocore<3.0.0,>=2.5.4->s3fs) (0.12.0)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /home/yasmine/.local/lib/python3.10/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->s3fs) (1.18.3)
# Requirement already satisfied: multidict<7.0,>=4.5 in /home/yasmine/.local/lib/python3.10/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->s3fs) (6.1.0)
# Requirement already satisfied: attrs>=17.3.0 in /home/yasmine/.local/lib/python3.10/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->s3fs) (23.1.0)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /home/yasmine/.local/lib/python3.10/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->s3fs) (2.4.4)
# Requirement already satisfied: aiosignal>=1.1.2 in /home/yasmine/.local/lib/python3.10/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->s3fs) (1.3.2)
# Requirement already satisfied: async-timeout<6.0,>=4.0 in /home/yasmine/.local/lib/python3.10/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->s3fs) (5.0.1)
# Requirement already satisfied: propcache>=0.2.0 in /home/yasmine/.local/lib/python3.10/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->s3fs) (0.2.1)
# Requirement already satisfied: frozenlist>=1.1.1 in /home/yasmine/.local/lib/python3.10/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->s3fs) (1.5.0)
# Requirement already satisfied: tzdata>=2022.7 in /home/yasmine/.local/lib/python3.10/site-packages (from pandas>=1.4.0->geopandas) (2024.1)
# Requirement already satisfied: pytz>=2020.1 in /usr/lib/python3/dist-packages (from pandas>=1.4.0->geopandas) (2022.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/yasmine/.local/lib/python3.10/site-packages (from pandas>=1.4.0->geopandas) (2.8.2)
# Requirement already satisfied: certifi in /usr/lib/python3/dist-packages (from pyogrio>=0.7.2->geopandas) (2020.6.20)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in /home/yasmine/.local/lib/python3.10/site-packages (from botocore<1.35.89,>=1.35.74->aiobotocore<3.0.0,>=2.5.4->s3fs) (1.0.1)
# Requirement already satisfied: urllib3!=2.2.0,<3,>=1.25.4 in /usr/lib/python3/dist-packages (from botocore<1.35.89,>=1.35.74->aiobotocore<3.0.0,>=2.5.4->s3fs) (1.26.5)
# Requirement already satisfied: typing-extensions>=4.1.0 in /home/yasmine/.local/lib/python3.10/site-packages (from multidict<7.0,>=4.5->aiohttp!=4.0.0a0,!=4.0.0a1->s3fs) (4.12.2)
# Requirement already satisfied: six>=1.5 in /usr/lib/python3/dist-packages (from python-dateutil>=2.8.2->pandas>=1.4.0->geopandas) (1.16.0)
# Requirement already satisfied: idna>=2.0 in /usr/lib/python3/dist-packages (from yarl<2.0,>=1.17.0->aiohttp!=4.0.0a0,!=4.0.0a1->s3fs) (3.3)
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: PyYAML in /home/yasmine/.local/lib/python3.10/site-packages (6.0.2)
# Requirement already satisfied: xlrd in /home/yasmine/.local/lib/python3.10/site-packages (2.0.1)
# Defaulting to user installation because normal site-packages is not writeable
# Collecting git+https://github.com/inseefrlab/cartiflette
#   Cloning https://github.com/inseefrlab/cartiflette to /tmp/pip-req-build-_mlfil20
#   Running command git clone --filter=blob:none --quiet https://github.com/inseefrlab/cartiflette /tmp/pip-req-build-_mlfil20
#   Resolved https://github.com/inseefrlab/cartiflette to commit f6b0c5d049bd6dcae7b437bd931957371da24278
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: xlrd<3.0.0,>=2.0.1 in /home/yasmine/.local/lib/python3.10/site-packages (from cartiflette==0.0.2) (2.0.1)
# Requirement already satisfied: retrying<2.0.0,>=1.3.4 in /home/yasmine/.local/lib/python3.10/site-packages (from cartiflette==0.0.2) (1.3.4)
# Requirement already satisfied: polars<2.0.0,>=1.8.1 in /home/yasmine/.local/lib/python3.10/site-packages (from cartiflette==0.0.2) (1.18.0)
# Requirement already satisfied: s3fs<2024.0.0,>=2023.3.0 in /home/yasmine/.local/lib/python3.10/site-packages (from cartiflette==0.0.2) (2023.12.2)
# Requirement already satisfied: requests-cache<2.0.0,>=1.1.0 in /home/yasmine/.local/lib/python3.10/site-packages (from cartiflette==0.0.2) (1.2.1)
# Requirement already satisfied: pyarrow<18.0.0,>=17.0.0 in /home/yasmine/.local/lib/python3.10/site-packages (from cartiflette==0.0.2) (17.0.0)
# Requirement already satisfied: charset-normalizer<4.0.0,>=3.2.0 in /home/yasmine/.local/lib/python3.10/site-packages (from cartiflette==0.0.2) (3.3.0)
# Requirement already satisfied: appdirs<2.0.0,>=1.4.4 in /usr/lib/python3/dist-packages (from cartiflette==0.0.2) (1.4.4)
# Requirement already satisfied: openpyxl<4.0.0,>=3.1.5 in /home/yasmine/.local/lib/python3.10/site-packages (from cartiflette==0.0.2) (3.1.5)
# Requirement already satisfied: python-dotenv<2.0.0,>=1.0.0 in /home/yasmine/.local/lib/python3.10/site-packages (from cartiflette==0.0.2) (1.0.1)
# Requirement already satisfied: PyYAML<7.0,>=6.0 in /home/yasmine/.local/lib/python3.10/site-packages (from cartiflette==0.0.2) (6.0.2)
# Requirement already satisfied: fiona[s3]<2.0.0,>=1.9.4.post1 in /home/yasmine/.local/lib/python3.10/site-packages (from cartiflette==0.0.2) (1.10.1)
# Requirement already satisfied: matplotlib<4.0.0,>=3.7.1 in /home/yasmine/.local/lib/python3.10/site-packages (from cartiflette==0.0.2) (3.10.0)
# Requirement already satisfied: unidecode<2.0.0,>=1.3.6 in /home/yasmine/.local/lib/python3.10/site-packages (from cartiflette==0.0.2) (1.3.8)
# Requirement already satisfied: pandas<3.0.0,>=2.2.2 in /home/yasmine/.local/lib/python3.10/site-packages (from cartiflette==0.0.2) (2.2.2)
# Requirement already satisfied: pebble<6.0.0,>=5.0.3 in /home/yasmine/.local/lib/python3.10/site-packages (from cartiflette==0.0.2) (5.1.0)
# Requirement already satisfied: fastexcel<0.12.0,>=0.11.6 in /home/yasmine/.local/lib/python3.10/site-packages (from cartiflette==0.0.2) (0.11.6)
# Requirement already satisfied: diskcache<6.0.0,>=5.6.3 in /home/yasmine/.local/lib/python3.10/site-packages (from cartiflette==0.0.2) (5.6.3)
# Requirement already satisfied: urllib3<2 in /usr/lib/python3/dist-packages (from cartiflette==0.0.2) (1.26.5)
# Requirement already satisfied: topojson<2.0,>=1.5 in /home/yasmine/.local/lib/python3.10/site-packages (from cartiflette==0.0.2) (1.9)
# Requirement already satisfied: owslib<0.29.0,>=0.28.1 in /home/yasmine/.local/lib/python3.10/site-packages (from cartiflette==0.0.2) (0.28.1)
# Requirement already satisfied: py7zr<0.21.0,>=0.20.4 in /home/yasmine/.local/lib/python3.10/site-packages (from cartiflette==0.0.2) (0.20.8)
# Requirement already satisfied: geopandas<2.0.0,>=1.0.1 in /home/yasmine/.local/lib/python3.10/site-packages (from cartiflette==0.0.2) (1.0.1)
# Requirement already satisfied: python-magic<0.5.0,>=0.4.14 in /home/yasmine/.local/lib/python3.10/site-packages (from cartiflette==0.0.2) (0.4.27)
# Requirement already satisfied: requests<3.0.0,>=2.28.2 in /home/yasmine/.local/lib/python3.10/site-packages (from cartiflette==0.0.2) (2.32.3)
# Requirement already satisfied: click-plugins>=1.0 in /home/yasmine/.local/lib/python3.10/site-packages (from fiona[s3]<2.0.0,>=1.9.4.post1->cartiflette==0.0.2) (1.1.1)
# Requirement already satisfied: attrs>=19.2.0 in /home/yasmine/.local/lib/python3.10/site-packages (from fiona[s3]<2.0.0,>=1.9.4.post1->cartiflette==0.0.2) (23.1.0)
# Requirement already satisfied: click~=8.0 in /usr/lib/python3/dist-packages (from fiona[s3]<2.0.0,>=1.9.4.post1->cartiflette==0.0.2) (8.0.3)
# Requirement already satisfied: certifi in /usr/lib/python3/dist-packages (from fiona[s3]<2.0.0,>=1.9.4.post1->cartiflette==0.0.2) (2020.6.20)
# Requirement already satisfied: cligj>=0.5 in /home/yasmine/.local/lib/python3.10/site-packages (from fiona[s3]<2.0.0,>=1.9.4.post1->cartiflette==0.0.2) (0.7.2)
# Requirement already satisfied: boto3>=1.3.1 in /home/yasmine/.local/lib/python3.10/site-packages (from fiona[s3]<2.0.0,>=1.9.4.post1->cartiflette==0.0.2) (1.35.88)
# Requirement already satisfied: pyproj>=3.3.0 in /home/yasmine/.local/lib/python3.10/site-packages (from geopandas<2.0.0,>=1.0.1->cartiflette==0.0.2) (3.6.1)
# Requirement already satisfied: packaging in /home/yasmine/.local/lib/python3.10/site-packages (from geopandas<2.0.0,>=1.0.1->cartiflette==0.0.2) (23.2)
# Requirement already satisfied: numpy>=1.22 in /home/yasmine/.local/lib/python3.10/site-packages (from geopandas<2.0.0,>=1.0.1->cartiflette==0.0.2) (1.26.2)
# Requirement already satisfied: pyogrio>=0.7.2 in /home/yasmine/.local/lib/python3.10/site-packages (from geopandas<2.0.0,>=1.0.1->cartiflette==0.0.2) (0.9.0)
# Requirement already satisfied: shapely>=2.0.0 in /home/yasmine/.local/lib/python3.10/site-packages (from geopandas<2.0.0,>=1.0.1->cartiflette==0.0.2) (2.0.5)
# Requirement already satisfied: cycler>=0.10 in /usr/lib/python3/dist-packages (from matplotlib<4.0.0,>=3.7.1->cartiflette==0.0.2) (0.11.0)
# Requirement already satisfied: python-dateutil>=2.7 in /home/yasmine/.local/lib/python3.10/site-packages (from matplotlib<4.0.0,>=3.7.1->cartiflette==0.0.2) (2.8.2)
# Requirement already satisfied: pillow>=8 in /usr/lib/python3/dist-packages (from matplotlib<4.0.0,>=3.7.1->cartiflette==0.0.2) (9.0.1)
# Requirement already satisfied: contourpy>=1.0.1 in /home/yasmine/.local/lib/python3.10/site-packages (from matplotlib<4.0.0,>=3.7.1->cartiflette==0.0.2) (1.3.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/lib/python3/dist-packages (from matplotlib<4.0.0,>=3.7.1->cartiflette==0.0.2) (1.3.2)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/lib/python3/dist-packages (from matplotlib<4.0.0,>=3.7.1->cartiflette==0.0.2) (4.29.1)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/lib/python3/dist-packages (from matplotlib<4.0.0,>=3.7.1->cartiflette==0.0.2) (2.4.7)
# Requirement already satisfied: et-xmlfile in /usr/lib/python3/dist-packages (from openpyxl<4.0.0,>=3.1.5->cartiflette==0.0.2) (1.0.1)
# Requirement already satisfied: pytz in /usr/lib/python3/dist-packages (from owslib<0.29.0,>=0.28.1->cartiflette==0.0.2) (2022.1)
# Requirement already satisfied: lxml in /usr/lib/python3/dist-packages (from owslib<0.29.0,>=0.28.1->cartiflette==0.0.2) (4.8.0)
# Requirement already satisfied: tzdata>=2022.7 in /home/yasmine/.local/lib/python3.10/site-packages (from pandas<3.0.0,>=2.2.2->cartiflette==0.0.2) (2024.1)
# Requirement already satisfied: brotli>=1.1.0 in /home/yasmine/.local/lib/python3.10/site-packages (from py7zr<0.21.0,>=0.20.4->cartiflette==0.0.2) (1.1.0)
# Requirement already satisfied: pyppmd<1.2.0,>=1.1.0 in /home/yasmine/.local/lib/python3.10/site-packages (from py7zr<0.21.0,>=0.20.4->cartiflette==0.0.2) (1.1.1)
# Requirement already satisfied: inflate64<1.1.0,>=1.0.0 in /home/yasmine/.local/lib/python3.10/site-packages (from py7zr<0.21.0,>=0.20.4->cartiflette==0.0.2) (1.0.1)
# Requirement already satisfied: texttable in /home/yasmine/.local/lib/python3.10/site-packages (from py7zr<0.21.0,>=0.20.4->cartiflette==0.0.2) (1.7.0)
# Requirement already satisfied: psutil in /home/yasmine/.local/lib/python3.10/site-packages (from py7zr<0.21.0,>=0.20.4->cartiflette==0.0.2) (5.9.5)
# Requirement already satisfied: pybcj<1.1.0,>=1.0.0 in /home/yasmine/.local/lib/python3.10/site-packages (from py7zr<0.21.0,>=0.20.4->cartiflette==0.0.2) (1.0.3)
# Requirement already satisfied: pycryptodomex>=3.16.0 in /home/yasmine/.local/lib/python3.10/site-packages (from py7zr<0.21.0,>=0.20.4->cartiflette==0.0.2) (3.21.0)
# Requirement already satisfied: multivolumefile>=0.2.3 in /home/yasmine/.local/lib/python3.10/site-packages (from py7zr<0.21.0,>=0.20.4->cartiflette==0.0.2) (0.2.3)
# Requirement already satisfied: pyzstd>=0.15.9 in /home/yasmine/.local/lib/python3.10/site-packages (from py7zr<0.21.0,>=0.20.4->cartiflette==0.0.2) (0.16.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/lib/python3/dist-packages (from requests<3.0.0,>=2.28.2->cartiflette==0.0.2) (3.3)
# Requirement already satisfied: platformdirs>=2.5 in /home/yasmine/.local/lib/python3.10/site-packages (from requests-cache<2.0.0,>=1.1.0->cartiflette==0.0.2) (4.3.6)
# Requirement already satisfied: cattrs>=22.2 in /home/yasmine/.local/lib/python3.10/site-packages (from requests-cache<2.0.0,>=1.1.0->cartiflette==0.0.2) (24.1.2)
# Requirement already satisfied: url-normalize>=1.4 in /home/yasmine/.local/lib/python3.10/site-packages (from requests-cache<2.0.0,>=1.1.0->cartiflette==0.0.2) (1.4.3)
# Requirement already satisfied: six>=1.7.0 in /usr/lib/python3/dist-packages (from retrying<2.0.0,>=1.3.4->cartiflette==0.0.2) (1.16.0)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /home/yasmine/.local/lib/python3.10/site-packages (from s3fs<2024.0.0,>=2023.3.0->cartiflette==0.0.2) (3.11.11)
# Requirement already satisfied: aiobotocore<3.0.0,>=2.5.4 in /home/yasmine/.local/lib/python3.10/site-packages (from s3fs<2024.0.0,>=2023.3.0->cartiflette==0.0.2) (2.16.1)
# Requirement already satisfied: fsspec==2023.12.2 in /home/yasmine/.local/lib/python3.10/site-packages (from s3fs<2024.0.0,>=2023.3.0->cartiflette==0.0.2) (2023.12.2)
# Requirement already satisfied: aioitertools<1.0.0,>=0.5.1 in /home/yasmine/.local/lib/python3.10/site-packages (from aiobotocore<3.0.0,>=2.5.4->s3fs<2024.0.0,>=2023.3.0->cartiflette==0.0.2) (0.12.0)
# Requirement already satisfied: wrapt<2.0.0,>=1.10.10 in /home/yasmine/.local/lib/python3.10/site-packages (from aiobotocore<3.0.0,>=2.5.4->s3fs<2024.0.0,>=2023.3.0->cartiflette==0.0.2) (1.14.1)
# Requirement already satisfied: botocore<1.35.89,>=1.35.74 in /home/yasmine/.local/lib/python3.10/site-packages (from aiobotocore<3.0.0,>=2.5.4->s3fs<2024.0.0,>=2023.3.0->cartiflette==0.0.2) (1.35.88)
# Requirement already satisfied: async-timeout<6.0,>=4.0 in /home/yasmine/.local/lib/python3.10/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->s3fs<2024.0.0,>=2023.3.0->cartiflette==0.0.2) (5.0.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /home/yasmine/.local/lib/python3.10/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->s3fs<2024.0.0,>=2023.3.0->cartiflette==0.0.2) (1.18.3)
# Requirement already satisfied: multidict<7.0,>=4.5 in /home/yasmine/.local/lib/python3.10/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->s3fs<2024.0.0,>=2023.3.0->cartiflette==0.0.2) (6.1.0)
# Requirement already satisfied: propcache>=0.2.0 in /home/yasmine/.local/lib/python3.10/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->s3fs<2024.0.0,>=2023.3.0->cartiflette==0.0.2) (0.2.1)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /home/yasmine/.local/lib/python3.10/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->s3fs<2024.0.0,>=2023.3.0->cartiflette==0.0.2) (2.4.4)
# Requirement already satisfied: aiosignal>=1.1.2 in /home/yasmine/.local/lib/python3.10/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->s3fs<2024.0.0,>=2023.3.0->cartiflette==0.0.2) (1.3.2)
# Requirement already satisfied: frozenlist>=1.1.1 in /home/yasmine/.local/lib/python3.10/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->s3fs<2024.0.0,>=2023.3.0->cartiflette==0.0.2) (1.5.0)
# Requirement already satisfied: s3transfer<0.11.0,>=0.10.0 in /home/yasmine/.local/lib/python3.10/site-packages (from boto3>=1.3.1->fiona[s3]<2.0.0,>=1.9.4.post1->cartiflette==0.0.2) (0.10.4)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in /home/yasmine/.local/lib/python3.10/site-packages (from boto3>=1.3.1->fiona[s3]<2.0.0,>=1.9.4.post1->cartiflette==0.0.2) (1.0.1)
# Requirement already satisfied: exceptiongroup>=1.1.1 in /home/yasmine/.local/lib/python3.10/site-packages (from cattrs>=22.2->requests-cache<2.0.0,>=1.1.0->cartiflette==0.0.2) (1.1.3)
# Requirement already satisfied: typing-extensions!=4.6.3,>=4.1.0 in /home/yasmine/.local/lib/python3.10/site-packages (from cattrs>=22.2->requests-cache<2.0.0,>=1.1.0->cartiflette==0.0.2) (4.12.2)
# /home/yasmine/.local/lib/python3.10/site-packages/pandas/core/computation/expressions.py:21: UserWarning: Pandas requires version '2.8.4' or newer of 'numexpr' (version '2.8.1' currently installed).
#   from pandas.core.computation.check import NUMEXPR_INSTALLED
# /home/yasmine/.local/lib/python3.10/site-packages/pandas/core/arrays/masked.py:60: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.2' currently installed).
#   from pandas.core import (
# /home/yasmine/.local/lib/python3.10/site-packages/matplotlib/projections/__init__.py:63: UserWarning: Unable to import Axes3D. This may be due to multiple versions of Matplotlib being installed (e.g. as a system package and as a pip package). As a result, the 3D projection is not available.
#   warnings.warn("Unable to import Axes3D. This may be due to multiple versions of "
# This is an experimental version of cartiflette published on PyPi.
# To use the latest stable version, you can install it directly from GitHub with the following command:
# pip install git+https://github.com/inseeFrLab/cartiflette.git

# %%
#Création du point d'accès
api_root_videoprotection = "https://tabular-api.data.gouv.fr/api/resources/"
ID_datagouv = "0f195145-1f5a-4762-9edc-40031ba4402f"
url_api_videoprotection = api_root_videoprotection + ID_datagouv + "/data/"
print(url_api_videoprotection)

#Test API
try:
    response = requests.get(url_api_videoprotection)
    response.raise_for_status()
    wb = response.json()
except requests.exceptions.RequestException as e:
    print(f"Erreur lors de la requête : {e}")
except ValueError:
    print("Erreur : Impossible de décoder le JSON.")

#Récupération des données sous format Json (plusieurs pages sont à parcourirs)

def recuperation_data(url_api):
    df = []  # Liste pour accumuler les données
    current_url = url_api

    while current_url:
        req = requests.get(current_url)
        wb = req.json()
        df.extend(wb['data'])
        current_url = wb["links"].get("next")
    return pd.DataFrame(df)

df_videoprotection = recuperation_data(url_api_videoprotection)

# Convertir les coordonnées en objets géométriques (de lon, lat à des points)
geometry = gpd.GeoSeries.from_xy(df_videoprotection.lon, df_videoprotection.lat)
df_videoprotection['geometry'] = geometry
gdf_videoprotection = gpd.GeoDataFrame(df_videoprotection, geometry='geometry')
gdf_videoprotection.set_crs('EPSG:4326', inplace=True)  # On identifie le CRS WGS 84
# Out:
# https://tabular-api.data.gouv.fr/api/resources/0f195145-1f5a-4762-9edc-40031ba4402f/data/
#      __id Code postal  Numéro  \
# 0       1       75001    1051
# 1       2       75001    1055
# 2       3       75001    1056
# 3       4       75001    1057
# 4       5       75002    2006
# ..    ...         ...     ...
# 702   703       75001   99000
# 703   704       75004  29297B
# 704   705       75015  45963B
# 705   706       75005  67726B
# 706   707       75012  97975A
#
#                                           Implantation  \
# 0                       Rue Saint-Denis, rue de Rivoli
# 1                       Rue Montmartre, rue de Turbigo
# 2                      Rue Montorgueil, rue de Turbigo
# 3    Quai François Mitterrand, rue de l'Amiral de C...
# 4                  Boulevard des Capucines, rue Scribe
# ..                                                 ...
# 702        Quai François Mitterrand, Pont du Carrousel
# 703         Place de l'Hôtel de Ville, avenue Victoria
# 704  Place Raoul Dautry, boulevard de Vaugirard, ru...
# 705     Place du Puits de L'Ermite, rue de Quatrefages
# 706                 Boulevard Soult, avenue Courteline
#
#     Précision de l’implantation Date de mise en service       lon        lat  \
# 0                    croisement                08/07/16  2.347502  48.858750
# 1                    croisement                10/03/17  2.346124  48.863243
# 2                    croisement                10/03/17  2.346291  48.863273
# 3                    croisement                08/06/18  2.339848  48.858990
# 4                    croisement              Début 2019  2.329943  48.870250
# ..                          ...                     ...       ...        ...
# 702                  croisement                   41334  2.333352  48.860112
# 703                  croisement                03/02/12  2.351083  48.856768
# 704                  croisement                20/04/12  2.319936  48.841863
# 705                  croisement                21/12/11  2.354492  48.842396
# 706                  croisement                16/11/12  2.410462  48.844272
#
#                      geometry
# 0     POINT (2.3475 48.85875)
# 1    POINT (2.34612 48.86324)
# 2    POINT (2.34629 48.86327)
# 3    POINT (2.33985 48.85899)
# 4    POINT (2.32994 48.87025)
# ..                        ...
# 702  POINT (2.33335 48.86011)
# 703  POINT (2.35108 48.85677)
# 704  POINT (2.31994 48.84186)
# 705   POINT (2.35449 48.8424)
# 706  POINT (2.41046 48.84427)
#
# [707 rows x 9 columns]

# %% [markdown]
# Une colonne indiquant les arrondissements avec le code INSEE_COG est également ajoutée pour harmoniser les données avec celles provenant d'autres sources.

# %%
# Fonction pour extraire et formater l'arrondissement
def extraire_arrondissement(code_postal):
    try:
        arrondissement = int(code_postal[-2:])  # Récupérer les deux derniers chiffres
        return f"751{arrondissement:02d}"
    except ValueError:
        return "Arrondissement inconnu"  # Gérer les cas où le code postal est invalide

# Ajouter la colonne 'INSEE_COG'
gdf_videoprotection['INSEE_COG'] = gdf_videoprotection['Code postal'].apply(extraire_arrondissement)
gdf_videoprotection.head(5)
# Out:
#    __id Code postal Numéro                                       Implantation  \
# 0     1       75001   1051                     Rue Saint-Denis, rue de Rivoli
# 1     2       75001   1055                     Rue Montmartre, rue de Turbigo
# 2     3       75001   1056                    Rue Montorgueil, rue de Turbigo
# 3     4       75001   1057  Quai François Mitterrand, rue de l'Amiral de C...
# 4     5       75002   2006                Boulevard des Capucines, rue Scribe
#
#   Précision de l’implantation Date de mise en service       lon        lat  \
# 0                  croisement                08/07/16  2.347502  48.858750
# 1                  croisement                10/03/17  2.346124  48.863243
# 2                  croisement                10/03/17  2.346291  48.863273
# 3                  croisement                08/06/18  2.339848  48.858990
# 4                  croisement              Début 2019  2.329943  48.870250
#
#                    geometry INSEE_COG
# 0   POINT (2.3475 48.85875)     75101
# 1  POINT (2.34612 48.86324)     75101
# 2  POINT (2.34629 48.86327)     75101
# 3  POINT (2.33985 48.85899)     75101
# 4  POINT (2.32994 48.87025)     75102

# %% [markdown]
# ## Statistique descriptive
# ### Analyse géographique
# Nous projetons désormais les points sur une carte de Paris en utilisant un fond de carte par le biais de cartiflette.

# %%
#Importation de la carte des arrondissement et création du fond de carte

arr_borders = carti_download(
    crs=4326,
    values=["75"],
    borders="COMMUNE_ARRONDISSEMENT",
    vectorfile_format="geojson",
    filter_by="DEPARTEMENT",
    source="EXPRESS-COG-CARTO-TERRITOIRE",
    year=2022,
)

#création du fond de carte
base = arr_borders.plot(color="white", edgecolor="black")
base.set_axis_off()
base.set_title("Répartitions des caméras de vidéoprotection dans les arrondissements de Paris")


#Intégration de la localisation des caméras de surveillance
gdf_videoprotection.plot(ax=base, marker='o', color = "red", markersize=5)
# Out:
# <Axes: title={'center': 'Répartitions des caméras de vidéoprotection dans les arrondissements de Paris'}>

# %%
# Création d'une carte Folium centrée sur Paris (on centre sur Notre-Dame)
map_cameraprotection = folium.Map(location=[48.8529, 2.3508], zoom_start=12)

# Contours des arrondissements
folium.GeoJson(
    arr_borders,
    name="Arrondissements de Paris",
    style_function=lambda feature: {
        'fillColor': 'white',
        'color': 'black',
        'weight': 1,
        'fillOpacity': 0.5,
    }
).add_to(map_cameraprotection)

#Ajout des caméras
for _, row in gdf_videoprotection.iterrows():
    tooltip_text = (
        f"Implantation: {row['Implantation']}<br>Date de mise en service: {row['Date de mise en service']}" 
    )
    
    folium.CircleMarker(
        location=[row.geometry.y, row.geometry.x],
        radius=5,
        color='red',
        fill=True,
        fill_color='red',
        fill_opacity=0.8,
        tooltip=tooltip_text
    ).add_to(map_cameraprotection)

folium.LayerControl().add_to(map_cameraprotection)
    
map_cameraprotection.save("carte_videoprotection_paris.html")
map_cameraprotection
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_7fd079adb31610e8432a5f246e430ec8 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_7fd079adb31610e8432a5f246e430ec8&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_7fd079adb31610e8432a5f246e430ec8 = L.map(
#                 &quot;map_7fd079adb31610e8432a5f246e430ec8&quot;,
#                 {
#                     center: [48.8529, 2.3508],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 12,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_0132512936d2f07c93fd23d5262c8dd6 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_0132512936d2f07c93fd23d5262c8dd6.addTo(map_7fd079adb31610e8432a5f246e430ec8);
#
#
#         function geo_json_162758141e1b176b2e62df1c00f41cd3_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;white&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 1};
#             }
#         }
#
#         function geo_json_162758141e1b176b2e62df1c00f41cd3_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_162758141e1b176b2e62df1c00f41cd3 = L.geoJson(null, {
#                 onEachFeature: geo_json_162758141e1b176b2e62df1c00f41cd3_onEachFeature,
#
#                 style: geo_json_162758141e1b176b2e62df1c00f41cd3_styler,
#             ...{
# }
#         });
#
#         function geo_json_162758141e1b176b2e62df1c00f41cd3_add (data) {
#             geo_json_162758141e1b176b2e62df1c00f41cd3
#                 .addData(data);
#         }
#             geo_json_162758141e1b176b2e62df1c00f41cd3_add({&quot;bbox&quot;: [2.224219105880447, 48.815562238059094, 2.469851066867315, 48.90214759334483], &quot;features&quot;: [{&quot;bbox&quot;: [2.3501644502627186, 48.8557851784223, 2.3684908866827366, 48.86932371269447], &quot;geometry&quot;: {&quot;coordinates&quot;: [[[2.3501644502627186, 48.8619854230763], [2.3534999320887886, 48.86121296229989], [2.356742165886384, 48.860146719997445], [2.3593445916232203, 48.85833949995604], [2.3617677575116796, 48.85724355060798], [2.3649412180556797, 48.856306224187], [2.36827851557945, 48.8557851784223], [2.3684908866827366, 48.855805185762065], [2.3667479472464605, 48.86307619286847], [2.3648904940380926, 48.866169984456235], [2.3643067849048007, 48.86730904968624], [2.3638721167271575, 48.867516286784095], [2.3632904468148337, 48.86781627183783], [2.3564958931139244, 48.86882946519756], [2.3542526716351295, 48.86932371269447], [2.350955108041352, 48.86340168750284], [2.3501644502627186, 48.8619854230763]]], &quot;type&quot;: &quot;Polygon&quot;}, &quot;id&quot;: &quot;0&quot;, &quot;properties&quot;: {&quot;AAV2020&quot;: &quot;001&quot;, &quot;ARR&quot;: &quot;751&quot;, &quot;BV2012&quot;: &quot;75056&quot;, &quot;CATEAAV2020&quot;: 11, &quot;CV&quot;: &quot;75ZZ&quot;, &quot;EPCI&quot;: &quot;200054781&quot;, &quot;ID&quot;: &quot;ARR_MUNI0000000009736045&quot;, &quot;INSEE_COG&quot;: &quot;75103&quot;, &quot;INSEE_COM&quot;: &quot;75056&quot;, &quot;INSEE_DEP&quot;: &quot;75&quot;, &quot;INSEE_REG&quot;: 11, &quot;LIBELLE_DEPARTEMENT&quot;: &quot;Paris&quot;, &quot;LIBELLE_REGION&quot;: &quot;\u00cele-de-France&quot;, &quot;NATURE_EPCI&quot;: &quot;ME&quot;, &quot;NOM&quot;: &quot;Paris 3e Arrondissement&quot;, &quot;PAYS&quot;: &quot;France&quot;, &quot;POPULATION&quot;: 34025, &quot;SOURCE&quot;: &quot;IGN:EXPRESS-COG-CARTO-TERRITOIRE&quot;, &quot;STATUT&quot;: &quot;Arrondissement municipal&quot;, &quot;TAAV2017&quot;: 5, &quot;TDAAV2017&quot;: 50, &quot;TDUU2017&quot;: 80, &quot;TUU2017&quot;: 8, &quot;UU2020&quot;: &quot;00851&quot;, &quot;ZE2020&quot;: 1109}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;bbox&quot;: [2.3279993725028856, 48.86340168750284, 2.3542526716351295, 48.87197209941962], &quot;geometry&quot;: {&quot;coordinates&quot;: [[[2.3479182282125945, 48.87068784517278], [2.340041163195276, 48.87197209941962], [2.3279993725028856, 48.869921153097984], [2.330107362963976, 48.86840948235575], [2.330425554638063, 48.86826017307477], [2.350955108041352, 48.86340168750284], [2.3542526716351295, 48.86932371269447], [2.3479182282125945, 48.87068784517278]]], &quot;type&quot;: &quot;Polygon&quot;}, &quot;id&quot;: &quot;1&quot;, &quot;properties&quot;: {&quot;AAV2020&quot;: &quot;001&quot;, &quot;ARR&quot;: &quot;751&quot;, &quot;BV2012&quot;: &quot;75056&quot;, &quot;CATEAAV2020&quot;: 11, &quot;CV&quot;: &quot;75ZZ&quot;, &quot;EPCI&quot;: &quot;200054781&quot;, &quot;ID&quot;: &quot;ARR_MUNI0000000009736046&quot;, &quot;INSEE_COG&quot;: &quot;75102&quot;, &quot;INSEE_COM&quot;: &quot;75056&quot;, &quot;INSEE_DEP&quot;: &quot;75&quot;, &quot;INSEE_REG&quot;: 11, &quot;LIBELLE_DEPARTEMENT&quot;: &quot;Paris&quot;, &quot;LIBELLE_REGION

# %% [markdown]
# On regarde la répartition des caméras de vidéoprotection par arrondissement en nombre puis en densité.

# %%
couverture_videoprotection_par_arrondissement = gdf_videoprotection['INSEE_COG'].value_counts()
df_couverture_videoprotection_par_arrondissement = couverture_videoprotection_par_arrondissement.reset_index()
df_couverture_videoprotection_par_arrondissement.columns = ['INSEE_COG', 'nombre']

#Ajout des geometry aux arrondissements en récupérant les données de arr_borders

df_couverture_videoprotection_par_arrondissement = df_couverture_videoprotection_par_arrondissement.merge(arr_borders[['INSEE_COG', 'geometry']], on='INSEE_COG', how='left')
gdf_couverture_videoprotection_par_arrondissement = gpd.GeoDataFrame(df_couverture_videoprotection_par_arrondissement,geometry='geometry')

carte_repartition_camera = gdf_couverture_videoprotection_par_arrondissement.plot(
    column = 'nombre',
    cmap='OrRd',
    legend=True,
    legend_kwds={"label": "Nombre de caméras par arrondissement", "orientation": "horizontal"},
)
carte_repartition_camera.set_axis_off()

# %%
print(gdf_couverture_videoprotection_par_arrondissement.crs)
#Projection du système de coordonnées géographique (lat/lon, 4326) un système métrique permettant de garantir le calcule des surface
gdf_couverture_videoprotection_par_arrondissement = gdf_couverture_videoprotection_par_arrondissement.to_crs(epsg=3395) 

# Calculer la surface et ajouter une colonne 'surface'
gdf_couverture_videoprotection_par_arrondissement['surface'] = gdf_couverture_videoprotection_par_arrondissement.geometry.area/ 1e6


#Calcul de la densité
gdf_couverture_videoprotection_par_arrondissement['densite_camera'] = (gdf_couverture_videoprotection_par_arrondissement['nombre'] / gdf_couverture_videoprotection_par_arrondissement['surface'])

carte_repartition_camera = gdf_couverture_videoprotection_par_arrondissement.plot(
    column = 'densite_camera',
    cmap='OrRd',
    legend=True,
    legend_kwds={"label": "densité de caméras par arrondissement", "orientation": "horizontal"},
)
carte_repartition_camera.set_axis_off()
# Out:
# EPSG:4326

# %% [markdown]
# Remarquons que nous retrouvons les résultats d'un modèle centre périphérie avec l'observation des densités de caméras de vidéoprotection au $\text{km}^2$. Les arrondissement comprenant le bois de Boulogne ainsi que le bois de Vincenne sont de façon attendu les moins densémenent équipés en caméra de videoprotection.

# %% [markdown]
# ### Analyse temporelle
#
# La base de données indique également la date de mise en service des caméra de vidéoprotection. Nous analysons cette données afin de pouvoir avoir une vision sur son exploitabilité.

# %%
#Unification des dates

def convert_date_format(date_str):
    # Cas 1 : Si la date commence par "Début", convertir en "01/01/yyyy"
    if isinstance(date_str, str) and date_str.startswith("Début"):
        year = date_str.split()[-1]  # Extraire l'année après 'Début'
        new_date_str = f"01/01/{year}"
        return pd.to_datetime(new_date_str, format='%d/%m/%Y', errors='raise')

    # Cas 2 : Si la date est sous forme de chaîne 'jj/mm/yy', convertir en datetime
    if isinstance(date_str, str) and len(date_str) == 8 and date_str[2] == '/' and date_str[5] == '/':
        return pd.to_datetime(date_str, format='%d/%m/%y', errors='raise')

    # Cas 3 : Si la date est une chaîne représentant un nombre (format Excel), la convertir en datetime
    if isinstance(date_str, str) and date_str.isdigit(): 
        num_date = float(date_str)  # Convertir la chaîne de caractères en nombre
        return pd.to_datetime('1899-12-30') + pd.to_timedelta(num_date, unit='D')

    # Cas 4 : Si la date est déjà un nombre (format Excel), la convertir directement en datetime
    if isinstance(date_str, (int, float)): 
        return pd.to_datetime('1899-12-30') + pd.to_timedelta(float(date_str), unit='D')

    # Si aucun format ne correspond
    return None

gdf_videoprotection['Date de mise en service'] = gdf_videoprotection['Date de mise en service'].apply(convert_date_format)

gdf_videoprotection
# Out:
#      __id Code postal  Numéro  \
# 0       1       75001    1051
# 1       2       75001    1055
# 2       3       75001    1056
# 3       4       75001    1057
# 4       5       75002    2006
# ..    ...         ...     ...
# 702   703       75001   99000
# 703   704       75004  29297B
# 704   705       75015  45963B
# 705   706       75005  67726B
# 706   707       75012  97975A
#
#                                           Implantation  \
# 0                       Rue Saint-Denis, rue de Rivoli
# 1                       Rue Montmartre, rue de Turbigo
# 2                      Rue Montorgueil, rue de Turbigo
# 3    Quai François Mitterrand, rue de l'Amiral de C...
# 4                  Boulevard des Capucines, rue Scribe
# ..                                                 ...
# 702        Quai François Mitterrand, Pont du Carrousel
# 703         Place de l'Hôtel de Ville, avenue Victoria
# 704  Place Raoul Dautry, boulevard de Vaugirard, ru...
# 705     Place du Puits de L'Ermite, rue de Quatrefages
# 706                 Boulevard Soult, avenue Courteline
#
#     Précision de l’implantation Date de mise en service       lon        lat  \
# 0                    croisement              2016-07-08  2.347502  48.858750
# 1                    croisement              2017-03-10  2.346124  48.863243
# 2                    croisement              2017-03-10  2.346291  48.863273
# 3                    croisement              2018-06-08  2.339848  48.858990
# 4                    croisement              2019-01-01  2.329943  48.870250
# ..                          ...                     ...       ...        ...
# 702                  croisement              2013-03-01  2.333352  48.860112
# 703                  croisement              2012-02-03  2.351083  48.856768
# 704                  croisement              2012-04-20  2.319936  48.841863
# 705                  croisement              2011-12-21  2.354492  48.842396
# 706                  croisement              2012-11-16  2.410462  48.844272
#
#                      geometry INSEE_COG
# 0     POINT (2.3475 48.85875)     75101
# 1    POINT (2.34612 48.86324)     75101
# 2    POINT (2.34629 48.86327)     75101
# 3    POINT (2.33985 48.85899)     75101
# 4    POINT (2.32994 48.87025)     75102
# ..                        ...       ...
# 702  POINT (2.33335 48.86011)     75101
# 703  POINT (2.35108 48.85677)     75104
# 704  POINT (2.31994 48.84186)     75115
# 705   POINT (2.35449 48.8424)     75105
# 706  POINT (2.41046 48.84427)     75112
#
# [707 rows x 10 columns]

# %%
gdf_videoprotection = gdf_videoprotection.dropna(subset=['Date de mise en service'])

# Extraire l'année de mise en service et compter le nombre de caméras mises en service par année
gdf_videoprotection['Année'] = gdf_videoprotection['Date de mise en service'].dt.year
cameras_par_annee = gdf_videoprotection.groupby('Année').size().cumsum()

# Tracer l'évolution du nombre cumulé de caméras
plt.figure(figsize=(10, 6))
plt.plot(cameras_par_annee.index.values, cameras_par_annee.values)


# Personnalisation du graphique
plt.title("Évolution du nombre cumulé de caméras de vidéoprotection", fontsize=14)
plt.xlabel("Année", fontsize=12)
plt.ylabel("Nombre cumulé de caméras", fontsize=12)
plt.grid(visible=True, linestyle='--', alpha=0.6)
plt.tight_layout()

# Afficher le graphique
plt.show()

# %%
# Calculer le nombre de caméras par année et par arrondissement (Code postal)
cam_per_arrondissement_par_annee = gdf_videoprotection.groupby(['Année', 'Code postal']).size().unstack(fill_value=0)

# Calculer la proportion de caméras pour chaque arrondissement par rapport au total de chaque année
cam_per_arrondissement_par_annee_cum = cam_per_arrondissement_par_annee.cumsum(axis=0)

# graphique en barres empilées
ax = cam_per_arrondissement_par_annee_cum.plot(kind='bar', stacked=True, figsize=(12, 7))

plt.title("Nombre des caméras de vidéoprotection par arrondissement et par année", fontsize=14)
plt.xlabel("Année", fontsize=12)
plt.ylabel("Nombre", fontsize=12)
plt.xticks(rotation=45)
plt.legend(title='Code Postal', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.tight_layout()
plt.show()
